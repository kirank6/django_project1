# %%
#Import packages
import requests
import io
import urllib.request
import flipp_extracter
from PIL import Image
from io import BytesIO
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Information needed for data extraction
item_name = 'apple'
zip_code = 60565

# %%
#results list of dictionarys of query items
Output = flipp_extracter.search(item_name, zip_code)

# %%
display(len(Output))
# Out:
# 127

# %%
# view dictionary 
Output[0]['item'].items()
# Out:
# dict_items([('id', 537536022), ('flyer_id', 3850927), ('flyer_valid_from', '2020-12-30T00:00:00-05:00'), ('flyer_valid_to', '2021-01-26T23:59:59-05:00'), ('brand', None), ('display_type', 1), ('merchant', 'Walmart'), ('merchant_id', 2175), ('merchant_logo', 'http://images.wishabi.net/merchants/2175/1399558010/medium'), ('name', 'Honeycrisp Apples'), ('image_url', 'http://f.wishabi.net/page_item_supplemental_infos/209112597/1608574047/extra_large'), ('cutout_image_url', 'http://f.wishabi.net/page_items/209112597/1609802877/extra_large.jpg'), ('media', []), ('description', None), ('current_price', ''), ('current_price_range', None), ('pre_price_text', None), ('category', ''), ('price_text', None), ('sale_story', 'Everyday Low Price'), ('original_price', None), ('original_price_range', None), ('in_store_only', True), ('disclaimer_text', 'All items sold separately.'), ('flyer_disclaimer_text', ''), ('valid_from', None), ('valid_to', None), ('timezone', -300), ('sku', None), ('ttm_label', 'Find a store'), ('ttm_url', 'https://www.walmart.com/cservice/ca_storefinder.gsp'), ('show_details', True), ('review_average_rating', None), ('review_count', 0), ('review_samples', []), ('reviews_most_recent', []), ('specs', []), ('features', []), ('related_items', []), ('shipping_info', {'tag_line': 'Shipping policy', 'details_url': 'https://help.walmart.com/app/answers/detail/a_id/1544/kw/shipping'}), ('return_info', {'tag_line': 'Return policy', 'details_url': 'https://help.walmart.com/app/answers/detail/a_id/9'}), ('top', -804.03), ('bottom', -1543.38), ('left', 125.69), ('right', 1020.3), ('percent_off', None), ('dollars_off', None)])

# %%
def select_df(list_dics_all):
    '''
    Results a datafram of selected items reading a list of 
    dictionaries of extracted items.
    '''
    #Reading data from Output dictionary
    selected_cols = ['brand', 'merchant', 'name', 'category', 'description', 
                                           'current_price', 'price_text', 'percent_off','image_url','cutout_image_url']
    df_all_items = pd.DataFrame(columns = selected_cols) # dataframe from selected items

    list_dic_selected_items =[]  # list of dictionaries with selected item desriptions only


    for i in range(len(Output)):
        items_dict = Output[i]['item']
        selected_dict = {}

        for key in items_dict:
            if key in selected_cols:
                selected_dict[key] = items_dict[key]                   
        list_dic_selected_items.append(selected_dict)   #update list with dictinaries for each group
    df_all_items = df_all_items.append(list_dic_selected_items, True)   # append list to dataframe 
    return df_all_items

# %%
df_sel = select_df(Output)

# %%
df_sel.tail(20)
# Out:
#        brand            merchant  \
# 107   Apple®             Staples
# 108   Apple®             Staples
# 109   Apple®             Staples
# 110   Apple®             Staples
# 111   Apple®             Staples
# 112   Apple®             Staples
# 113   Apple®             Staples
# 114   Apple®             Staples
# 115   Apple®             Staples
# 116   Apple®             Staples
# 117     None  Bath & Body Works
# 118     None  Bath & Body Works
# 119     None  Bath & Body Works
# 120  Briogeo         Ulta Beauty
# 121     None   Fry's Electronics
# 122     None            Best Buy
# 123     None          Five Below
# 124     None          Five Below
# 125     None          Five Below
# 126     None  Bath & Body Works
#
#                                                   name category  \
# 107                      Apple® Watch black sport band
# 108                     Apple® 30W USB-C power adapter
# 109            Apple® Watch SE GPS, space gray, 44 mm.
# 110             Apple® Watch Series 6 GPS, 40 mm, blue
# 111        Apple® AirPods® with wireless charging case
# 112                     Apple® 20W USB-C power adapter
# 113       Apple® smart keyboard case for 11" iPad Pro™
# 114                 Apple® AirPods® with charging case
# 115  Apple® Watch Series 6 GPS, 44 mm, space gray, ...
# 116             Apple® Watch Series 6 GPS, 44 mm, blue
# 117            Apple Hibiscus Gentle Foaming Hand Soap
# 118                  Country Apple Fine Fragrance Mist
# 119    Winter Candy Apple Wallflowers Fragrance Refill
# 120  Briogeo Be Gentle Be Kind™ Matcha + Apple Repl...
# 121   EZQuesb USB-C to Dual Link DVI Adapter Design...
# 122  VIZIO - 70" Class V-Series LED 4K UHD SmartCas...
# 123                  marvel® case for AirPods® gen 1/2
# 124                 fun case for AirPods® collection 2
# 125                 fun case for AirPods® collection 3
# 126                       Tis the Season 3-Wick Candle
#
#                                            description current_price  \
# 107                                     24463336-40 mm          49.0
# 108                                           24360672          51.0
# 109                                           24463248         279.0
# 110                                      24463336-blue         349.0
# 111                                           24395234         169.0
# 112                                           24468900          19.0
# 113                                           24453929         190.0
# 114                                           24395231         129.0
# 115                                           24463245         379.0
# 116                                           24463337         379.0
# 117  A juicy, floral blend of apple nectar, hibiscu...           7.5
# 118  A crisp combination of McIntosh apple & sweet ...           7.0
# 119  Home fragrance that lasts for weeks and weeks!...           2.5
# 120                                  12.5 oz.\n2575490          28.0
# 121                                               None
# 122  Discover the wonder of 4K entertainment with t...        599.99
# 123  ur AirPods® already save the day, so make it o...           5.0
# 124  protect ur AirPods® & make 'em look super cute...           4.0
# 125  protect ur AirPods® & make 'em look super cute...           4.0
# 126  The scent of Rich Red Apple, Sweet Cinnamon & ...          11.5
#
#     price_text  percent_off  \
# 107       None          NaN
# 108       None          NaN
# 109       None         10.0
# 110       None         13.0
# 111       None         15.0
# 112       None          NaN
# 113       None          NaN
# 114       None         19.0
# 115       None         12.0
# 116       None         12.0
# 117       None          NaN
# 118       None         50.0
# 119       None         67.0
# 120       None          NaN
# 121       None          NaN
# 122       None          9.0
# 123       None          NaN
# 124       None          NaN
# 125       None          NaN
# 126       None         53.0
#
#                                              image_url  \
# 107  http://f.wishabi.net/page_items/211561363/1610...
# 108  http://f.wishabi.net/page_items/211561376/1610...
# 109  http://f.wishabi.net/page_items/211561361/1610...
# 110  http://f.wishabi.net/page_items/211561370/1610...
# 111  http://f.wishabi.net/page_items/211561374/1610...
# 112  http://f.wishabi.net/page_pdf_images/11225259/...
# 113  http://f.wishabi.net/page_pdf_images/11225259/...
# 114  http://f.wishabi.net/page_pdf_images/11225259/...
# 115  http://f.wishabi.net/page_items/211018204/1610...
# 116  http://f.wishabi.net/page_pdf_images/11225259/...
# 117  http://f.wishabi.net/page_pdf_images/11240872/...
# 118  http://f.wishabi.net/page_pdf_images/11240879/...
# 119  http://f.wishabi.net/page_pdf_images/11240881/...
# 120  http://f.wishabi.net/page_items/207886037/1609...
# 121  http://f.wishabi.net/page_items/211520245/1610...
# 122  http://f.wishabi.net/page_pdf_images/11224695/...
# 123  http://f.wishabi.net/page_pdf_images/11220081/...
# 124  http://f.wishabi.net/page_pdf_images/11220080/...
# 125  http://f.wishabi.net/page_pdf_images/11220080/...
# 126  http://f.wishabi.net/page_pdf_images/11240867/...
#
#                                       cutout_image_url
# 107  http://f.wishabi.net/page_items/211561363/1610...
# 108  http://f.wishabi.net/page_items/211561376/1610...
# 109  http://f.wishabi.net/page_items/211561361/1610...
# 110  http://f.wishabi.net/page_items/211561370/1610...
# 111  http://f.wishabi.net/page_items/211561374/1610...
# 112  http://f.wishabi.net/page_items/211561375/1610...
# 113  http://f.wishabi.net/page_items/211561384/1610...
# 114  http://f.wishabi.net/page_items/211561373/1610...
# 115  http://f.wishabi.net/page_items/211018204/1610...
# 116  http://f.wishabi.net/page_items/211561368/1610...
# 117  http://f.wishabi.net/page_items/211835702/1610...
# 118  http://f.wishabi.net/page_items/211835755/1610...
# 119  http://f.wishabi.net/page_items/211835766/1610...
# 120  http://f.wishabi.net/page_items/207886037/1609...
# 121  http://f.wishabi.net/page_items/211520245/1610...
# 122  http://f.wishabi.net/page_items/211556782/1610...
# 123  http://f.wishabi.net/page_items/211443904/1610...
# 124  http://f.wishabi.net/page_items/211443897/1610...
# 125  http://f.wishabi.net/page_items/211443898/1610...
# 126  http://f.wishabi.net/page_items/211835667/1610...

# %%
len(df_sel['current_price'])
# Out:
# 127

# %%
len(df_sel[df_sel['current_price'] == ''])
# Out:
# 35

# %%
df_sel['ext_price'] = np.nan
df_sel['ext_weight'] = np.nan

# %%
# for i in range(len(df_sel)):
#     if df_sel['description'][i] != None:
#         desc_text = df_se

# %%
df_sel.tail()
# Out:
#     brand            merchant  \
# 122  None            Best Buy
# 123  None          Five Below
# 124  None          Five Below
# 125  None          Five Below
# 126  None  Bath & Body Works
#
#                                                   name category  \
# 122  VIZIO - 70" Class V-Series LED 4K UHD SmartCas...
# 123                  marvel® case for AirPods® gen 1/2
# 124                 fun case for AirPods® collection 2
# 125                 fun case for AirPods® collection 3
# 126                       Tis the Season 3-Wick Candle
#
#                                            description current_price  \
# 122  Discover the wonder of 4K entertainment with t...        599.99
# 123  ur AirPods® already save the day, so make it o...           5.0
# 124  protect ur AirPods® & make 'em look super cute...           4.0
# 125  protect ur AirPods® & make 'em look super cute...           4.0
# 126  The scent of Rich Red Apple, Sweet Cinnamon & ...          11.5
#
#     price_text  percent_off  \
# 122       None          9.0
# 123       None          NaN
# 124       None          NaN
# 125       None          NaN
# 126       None         53.0
#
#                                              image_url  \
# 122  http://f.wishabi.net/page_pdf_images/11224695/...
# 123  http://f.wishabi.net/page_pdf_images/11220081/...
# 124  http://f.wishabi.net/page_pdf_images/11220080/...
# 125  http://f.wishabi.net/page_pdf_images/11220080/...
# 126  http://f.wishabi.net/page_pdf_images/11240867/...
#
#                                       cutout_image_url  ext_price  ext_weight
# 122  http://f.wishabi.net/page_items/211556782/1610...        NaN         NaN
# 123  http://f.wishabi.net/page_items/211443904/1610...        NaN         NaN
# 124  http://f.wishabi.net/page_items/211443897/1610...        NaN         NaN
# 125  http://f.wishabi.net/page_items/211443898/1610...        NaN         NaN
# 126  http://f.wishabi.net/page_items/211835667/1610...        NaN         NaN

# %%
# Extracting price and weight information from combined text.
for i in range(len(df_sel)):
        comb_text = str(df_sel['name'][i])+ ',' + str(df_sel['description'][i]) + ','+  str(df_sel['price_text'][i])
        
        # extract oz 
        tw1 = re.findall('[/ ]\d{1,2,3}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',comb_text)
        tw2 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',comb_text)
        tw3 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw4 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw5 = re.findall('[/,]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw6 = re.findall('[/-]\d{1,2}[/.]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw7 = re.findall('[/,]\d{1,2}[/.]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw8 = re.findall('[/,]\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw9 = re.findall('[/ ]\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',comb_text)
        tw10 = re.findall('\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw11 = re.findall('\d{1,2}[/.]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw12 = re.findall('[/-]\d{1}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw13 =  re.findall('[/ ]\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw14 = re.findall('[/-]\d{1,2}[/.]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw15 = re.findall('[/-]\d{2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw16 = re.findall('\d{3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw17 = re.findall('[/-]\d{2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw18 = re.findall('[/ ]\d{1}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw19 = re.findall('\d{2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw20 = re.findall('\d{1}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
              
        #extract lb 
        tw21 = re.findall('\d{3}[/ ]\d{2}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw22 = re.findall('[/$]\d{3}[//](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw23 = re.findall('[/$]\d{3}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw24 = re.findall('[/$]\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw25 = re.findall('\d{3}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw26 = re.findall('\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        
        tw27 = re.findall('[/$]\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw28 = re.findall('[/,](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw29 = re.findall('[/ ]\d{1}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw30 = re.findall('\d{3}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw31 = re.findall('\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw32 = re.findall('\d{1}[/.]\d{2} [/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw33 = re.findall('[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)[/ ]',comb_text)
        tw34 = re.findall('\d{3}[\n](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw35 = re.findall('(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)[\n]\d{3}',comb_text)
        tw36 = re.findall('\d{1}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.|Lbs.)[\n][/$]\d{3}',comb_text)
                   
        ftw = tw1 or tw2 or tw3 or tw4 or tw5 or tw6  \
              or tw7 or tw8 or tw9 or tw10 or tw11 or tw12 \
              or tw13 or tw14 or tw15 or tw16 or tw17 or tw18  \
              or tw19 or tw20 or tw21 or tw22 or tw23 or tw24  \
              or tw25 or tw26 or tw27 or tw28 or tw29 or tw30  \
              or tw31 or tw32 or tw33 or tw34 or tw35 or tw36
        
        #print(i, ftw, comb_text)
        if ftw != []:
            df_sel['ext_weight'][i] = ftw[0]
        if df_sel['current_price'][i] == '':
            mtxt_name = df_sel['name'][i]

            #extract price 
            mtp1 = re.findall('[/$]\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',mtxt_name)
            mtp2 = re.findall('\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',mtxt_name)
            mtp3 = re.findall('[/$]\d{1,2}[/.]\d{2}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',mtxt_name)
            mtp4 = re.findall('[/$]\d{1,2}[/.]\d{2}',mtxt_name)

            mftp = mtp1 or mtp2 or mtp3 or mtp4
            
            if mftp != []:         
                df_sel['ext_price'][i] = mftp[0] 

            #print(i, mftp, mtxt_name)
        
# #         # extract weight unit
# #         tu1 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
# #         tu2 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
# #         tu3 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
# #         tu4 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
        
# #         ftu = tu1 or tu2 or tu3 or tu4
        
# #         if ftp != []:                    
# #             df_sel['calc_price'][i] = ftp[0]
# #         if ftu != []:         
#             df_sel['calc_weight'][i] = ftu[0]

# %%
# # Extracting price and weight information from name column.
# for i in range(len(df_sel)):
#     if df_sel['current_price'][i] == '':
#         txt_name = df_sel['name'][i]
        
#         #extract price only
#         tp1 = re.findall('[/$]\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',txt_name)
#         tp2 = re.findall('\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',txt_name)
#         tp3 = re.findall('[/$]\d{1,2}[/.]\d{2}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',txt_name)
#         tp4 = re.findall('[/$]\d{1,2}[/.]\d{2}',txt_name)
              
#         ftp = tp1 or tp2 or tp3 or tp4
        
#         # extract weight unit
#         tu1 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
#         tu2 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
#         tu3 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
#         tu4 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
        
#         ftu = tu1 or tu2 or tu3 or tu4
        
#         if ftp != []:                    
#             df_sel['calc_price'][i] = ftp[0]
#         if ftu != []:         
#             df_sel['calc_weight'][i] = ftu[0]

# %%
df_sel['ext_price'].unique()
# Out:
# array([nan, '$2.19', '$399/LB', '493 Lb', '$2.09', '690 LB', '$74.99'],
#       dtype=object)

# %%
df_sel['ext_price'].isnull().sum()
# Out:
# 121

# %%
df_sel['ext_weight'].unique()
# Out:
# array([nan, ' lb. ', ',lb', ' LB. ', ' lb ', '$399/LB', '493 Lb', ',LB',
#        ' 2 lb', '149 49 Lb', ' LB ', ' 3 LB', '/lb', '690 LB', '32.7 oz',
#        '37.3 oz', '1.68 oz', ' 19 oz. ', ',32 oz', ' 24 oz', '19.4 Oz',
#        '-13.5 oz', ' 10 Oz', ' 64 oZ. ', ',64 oz', '13.5 Oz', ' 64oz',
#        ' 64 oz. ', ',12.5 oz'], dtype=object)

# %%
df_sel['ext_weight'].isnull().sum()
# Out:
# 91

# %%
for i in range(len(df_sel)):
    old_price = df_sel['current_price'][i]
    new_price = df_sel['ext_price'][i]
    weight_info = df_sel['ext_weight'][i]
    print(i, old_price,',', new_price,',', weight_info)
# Out:
# 0  , nan , nan
# 1 3.99 , nan ,  lb.
# 2  , nan , nan
# 3 1.29 , nan , ,lb
# 4  , $2.19 , nan
# 5 1.29 , nan , nan
# 6 2.49 , nan , ,lb
# 7 3.49 , nan , ,lb
# 8 1.49 , nan , nan
# 9  , nan ,  LB.
# 10 0.99 , nan , ,lb
# 11 2.99 , nan ,  lb
# 12  , nan ,  lb
# 13  , $399/LB , $399/LB
# 14  , nan ,  lb
# 15  , 493 Lb , 493 Lb
# 16  , nan , nan
# 17 2.99 , nan , ,lb
# 18  , nan , nan
# 19 1.99 , nan , ,LB
# 20  , nan ,  lb.
# 21  , nan ,  2 lb
# 22  , nan , 149 49 Lb
# 23  , nan ,  LB
# 24  , nan ,  3 LB
# 25  , $2.09 , /lb
# 26  , nan , nan
# 27  , 690 LB , 690 LB
# 28 5.0 , nan , nan
# 29 8.98 , nan , 32.7 oz
# 30 6.98 , nan , 37.3 oz
# 31 9.87 , nan , nan
# 32  , nan , nan
# 33  , nan , nan
# 34 19.0 , nan , nan
# 35 9.98 , nan , 1.68 oz
# 36 19.99 , nan , nan
# 37  , nan ,  19 oz.
# 38 4.99 , nan , nan
# 39 4.98 , nan , nan
# 40 4.99 , nan , ,32 oz
# 41 6.0 , nan , nan
# 42 5.0 , nan , nan
# 43 3.99 , nan ,  24 oz
# 44  , nan , 19.4 Oz
# 45  , nan , -13.5 oz
# 46  , nan , nan
# 47  , nan ,  10 Oz
# 48  , nan , nan
# 49 102.0 , nan , nan
# 50 499.99 , nan , nan
# 51 17.98 , nan , nan
# 52 21.74 , nan , nan
# 53 4.94 , nan , nan
# 54 59.0 , nan , nan
# 55 6.99 , nan , nan
# 56 150.0 , nan , nan
# 57 4.95 , nan , nan
# 58 2.5 , nan , nan
# 59 6.75 , nan , nan
# 60 4.95 , nan , nan
# 61 2.5 , nan , nan
# 62 2.5 , nan , nan
# 63 7.75 , nan , nan
# 64 6.25 , nan , nan
# 65 14.99 , nan , nan
# 66  , nan , nan
# 67  , nan ,  64 oZ.
# 68 0.88 , nan , ,64 oz
# 69 4.0 , nan , ,64 oz
# 70  , nan , nan
# 71  , nan , nan
# 72  , nan , 13.5 Oz
# 73  , nan ,  64oz
# 74  , nan , nan
# 75  , nan , nan
# 76 1.98 , nan ,  64 oz.
# 77 229.99 , nan , nan
# 78 129.99 , nan , nan
# 79 29.0 , nan , nan
# 80 209.0 , nan , nan
# 81 5.0 , nan , nan
# 82 349.0 , nan , nan
# 83 3.0 , nan , nan
# 84 21.74 , nan , nan
# 85 10.0 , nan , nan
# 86 379.0 , nan , nan
# 87 249.0 , nan , nan
# 88 279.0 , nan , nan
# 89 4.0 , nan , nan
# 90 249.0 , nan , nan
# 91 379.0 , nan , nan
# 92 349.0 , nan , nan
# 93 4.0 , nan , nan
# 94 2.5 , nan , nan
# 95 279.99 , nan , nan
# 96 349.0 , nan , nan
# 97 199.99 , nan , nan
# 98 399.99 , nan , nan
# 99 35.0 , nan , nan
# 100 129.0 , nan , nan
# 101 30.0 , nan , nan
# 102 100.0 , nan , nan
# 103 29.0 , nan , nan
# 104 129.0 , nan , nan
# 105 29.0 , nan , nan
# 106 49.0 , nan , nan
# 107 49.0 , nan , nan
# 108 51.0 , nan , nan
# 109 279.0 , nan , nan
# 110 349.0 , nan , nan
# 111 169.0 , nan , nan
# 112 19.0 , nan , nan
# 113 190.0 , nan , nan
# 114 129.0 , nan , nan
# 115 379.0 , nan , nan
# 116 379.0 , nan , nan
# 117 7.5 , nan , nan
# 118 7.0 , nan , nan
# 119 2.5 , nan , nan
# 120 28.0 , nan , ,12.5 oz
# 121  , $74.99 , nan
# 122 599.99 , nan , nan
# 123 5.0 , nan , nan
# 124 4.0 , nan , nan
# 125 4.0 , nan , nan
# 126 11.5 , nan , nan
