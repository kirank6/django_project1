# %%
#Import packages
import requests
import io
import urllib.request
import flipp_extracter
from PIL import Image
from io import BytesIO
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Information needed for data extraction
item_name = 'cheese'
zip_code = 60565

# %%
#results list of dictionarys of query items
Output = flipp_extracter.search(item_name, zip_code)

# %%
display(len(Output))
# Out:
# 122

# %%
# view dictionary 
Output[0]['item'].items()
# Out:
# dict_items([('id', 541625883), ('flyer_id', 3882254), ('flyer_valid_from', '2021-01-10T00:00:00-05:00'), ('flyer_valid_to', '2021-01-16T23:59:59-05:00'), ('brand', 'Kraft'), ('display_type', 1), ('merchant', 'Family Dollar'), ('merchant_id', 2150), ('merchant_logo', 'http://images.wishabi.net/merchants/2150/1509716319/medium'), ('name', 'Kraft Velveeta Shells & Cheese 12 oz. or Kraft Deluxe Macaroni & Cheese 14 oz.'), ('image_url', 'http://f.wishabi.net/page_pdf_images/11190640/6d0dbc66-4cab-11eb-af8b-0e1ba86a8db4/x_large'), ('cutout_image_url', 'http://f.wishabi.net/page_items/210844158/1610033718/extra_large.jpg'), ('media', []), ('description', ''), ('current_price', '2.75'), ('current_price_range', None), ('pre_price_text', 'Sale!'), ('category', ''), ('price_text', None), ('sale_story', None), ('original_price', None), ('original_price_range', None), ('in_store_only', False), ('disclaimer_text', None), ('flyer_disclaimer_text', ''), ('valid_from', None), ('valid_to', None), ('timezone', -300), ('sku', None), ('ttm_label', 'See It'), ('ttm_url', None), ('show_details', True), ('review_average_rating', None), ('review_count', 0), ('review_samples', []), ('reviews_most_recent', []), ('specs', []), ('features', []), ('related_items', []), ('shipping_info', {'tag_line': '', 'details_url': ''}), ('return_info', {'tag_line': 'Return policy', 'details_url': 'https://www.familydollar.com/legal/Return-Policy'}), ('top', -832.37), ('bottom', -1283.7), ('left', 6954.79), ('right', 7528.2), ('percent_off', None), ('dollars_off', None)])

# %%
def select_df(list_dics_all):
    '''
    Results a datafram of selected items reading a list of 
    dictionaries of extracted items.
    '''
    #Reading data from Output dictionary
    selected_cols = ['brand', 'merchant', 'name', 'category', 'description', 
                                           'current_price', 'price_text', 'percent_off','image_url','cutout_image_url']
    df_all_items = pd.DataFrame(columns = selected_cols) # dataframe from selected items

    list_dic_selected_items =[]  # list of dictionaries with selected item desriptions only


    for i in range(len(Output)):
        items_dict = Output[i]['item']
        selected_dict = {}

        for key in items_dict:
            if key in selected_cols:
                selected_dict[key] = items_dict[key]                   
        list_dic_selected_items.append(selected_dict)   #update list with dictinaries for each group
    df_all_items = df_all_items.append(list_dic_selected_items, True)   # append list to dataframe 
    return df_all_items

# %%
df_sel = select_df(Output)

# %%
df_sel.tail(20)
# Out:
#          brand                      merchant  \
# 102       None                    Jewel-Osco
# 103       None         Woodman's Food Market
# 104       None           Tony's Fresh Market
# 105       None                    Jewel-Osco
# 106       None                 Butera Market
# 107       None         Woodman's Food Market
# 108       None         Woodman's Food Market
# 109       None                          ALDI
# 110       None                  CVS Pharmacy
# 111       None  Angelo Caputo's Fresh Market
# 112       None  Angelo Caputo's Fresh Market
# 113       None           Garden Fresh Market
# 114       None                        Meijer
# 115       None                 Trader Joe's
# 116  Birds Eye                       Walmart
# 117       None                          ALDI
# 118       None                     Walgreens
# 119       None         Woodman's Food Market
# 120       None                    Sam's Club
# 121       None                      Best Buy
#
#                                                   name category  \
# 102  Pure Leaf Tea 59 oz., Tropicana Premium Lemona...
# 103  $2.99\nMerkt's Sharp Cheddar Cheese\nSpread\n1...
# 104         80z. Brick Philadelphio FLn Cream Cheese 0
# 105     Michael Angelo's or Kraft Mac & Cheese Entrées
# 106   La Preferida 20 L. Nopalitos or 15 Cheese Sau...
# 107  $2.49\nFull Circle Four Cheese Pasta Sauce\n24...
# 108  4/$3\nKraft SpongeBob Mac & Cheese\n5.5oz Pack...
# 109  Bremer Loaded Potato Flavor or Jalapeno Popper...
# 110  Jif peanut butter 16 oz, Smucker's preserves 1...
# 111   CAULIPLAVER LIVE LIFE ON TUE UE CAULIP WER PI...
# 112   salad & RNE BbASTED RTIU VL aset Rinch ECRET ...
# 113  Apollo\nSpiral Pie\n•Cheese\n•Spinach\n799\n85...
# 114  Betty Crocker Helper 5-7.6 oz. or Potatoes 4.6...
# 115                         Black Truffle Cashew Pesto
# 116               NEW! Birds Eye Cheddar Broccoli Bake
# 117  Mama Cozzi's Pizza Kitchen 12" Gluten Free Del...
# 118                              Frozen Meal Favorites
# 119  $1.50\nBorden Mild Cheddar Slices\n6oz Package...
# 120  Viking Acacia Wood 2-Piece Paddle and Cutting ...
# 121  KitchenAid Metal Food Grinder Attachment - Silver
#
#                                            description current_price  \
# 102                 Select Varieties\n\n\nmix or match           5.0
# 103                                               None
# 104                                               None
# 105                        8.5-11 oz. Select Varieties           7.0
# 106                                               None
# 107                                               None
# 108                                               None
# 109                                      22 oz. Frozen          4.99
# 110                                               None           5.0
# 111                                               None
# 112                                               None
# 113                                               None
# 114                                  Select varieties.           1.0
# 115  Our new Black Truffle Cashew Pesto Sauce is a ...          3.99
# 116                                              13 oz          3.98
# 117                Cheese or Pepperoni\n17.5–17.78 oz.          5.99
# 118  • White Castle Chicken Sandwiches or Burgers, ...
# 119                                               None
# 120  For an elegant serving piece to display at you...         29.98
# 121  Fresh from scratch cooking does not have to ta...         79.99
#
#             price_text  percent_off  \
# 102               None          NaN
# 103               None          NaN
# 104               None          NaN
# 105               None          NaN
# 106               None          NaN
# 107               None          NaN
# 108               None          NaN
# 109               None          NaN
# 110  or 2.79 WITH CARD          NaN
# 111               None          NaN
# 112               None          NaN
# 113               None          NaN
# 114               None          NaN
# 115               None          NaN
# 116               None          NaN
# 117               Each          NaN
# 118               None         50.0
# 119               None          NaN
# 120               None          NaN
# 121               None         20.0
#
#                                              image_url  \
# 102  http://f.wishabi.net/page_pdf_images/11207418/...
# 103  http://f.wishabi.net/page_items/211919794/1610...
# 104  http://f.wishabi.net/page_items/211794521/1610...
# 105  http://f.wishabi.net/page_pdf_images/11207407/...
# 106  http://f.wishabi.net/page_items/211787409/1610...
# 107  http://f.wishabi.net/page_items/211920164/1610...
# 108  http://f.wishabi.net/page_items/211919467/1610...
# 109  http://f.wishabi.net/page_items/210013831/1610...
# 110  http://f.wishabi.net/page_items/210111909/1609...
# 111  http://f.wishabi.net/page_items/211861554/1610...
# 112  http://f.wishabi.net/page_items/211861527/1610...
# 113  http://f.wishabi.net/page_items/211648857/1610...
# 114  http://f.wishabi.net/page_items/210658660/1610...
# 115  http://f.wishabi.net/page_pdf_images/11218863/...
# 116  http://f.wishabi.net/page_pdf_images/11100085/...
# 117  http://f.wishabi.net/page_items/209999351/1609...
# 118  http://f.wishabi.net/page_pdf_images/11132380/...
# 119  http://f.wishabi.net/page_items/211919793/1610...
# 120  http://f.wishabi.net/page_pdf_images/11220548/...
# 121  http://f.wishabi.net/page_pdf_images/11224699/...
#
#                                       cutout_image_url
# 102  http://f.wishabi.net/page_items/211269527/1610...
# 103  http://f.wishabi.net/page_items/211919794/1610...
# 104  http://f.wishabi.net/page_items/211794521/1610...
# 105  http://f.wishabi.net/page_items/211271402/1610...
# 106  http://f.wishabi.net/page_items/211787409/1610...
# 107  http://f.wishabi.net/page_items/211920164/1610...
# 108  http://f.wishabi.net/page_items/211919467/1610...
# 109  http://f.wishabi.net/page_items/210013831/1610...
# 110  http://f.wishabi.net/page_items/210111909/1609...
# 111  http://f.wishabi.net/page_items/211861554/1610...
# 112  http://f.wishabi.net/page_items/211861527/1610...
# 113  http://f.wishabi.net/page_items/211648857/1610...
# 114  http://f.wishabi.net/page_items/210658660/1610...
# 115  http://f.wishabi.net/page_items/211440768/1610...
# 116  http://f.wishabi.net/page_items/209111486/1609...
# 117  http://f.wishabi.net/page_items/209999351/1609...
# 118  http://f.wishabi.net/page_items/209765295/1610...
# 119  http://f.wishabi.net/page_items/211919793/1610...
# 120  http://f.wishabi.net/page_items/211444404/1610...
# 121  http://f.wishabi.net/page_items/211556814/1610...

# %%
len(df_sel['current_price'])
# Out:
# 122

# %%
len(df_sel[df_sel['current_price'] == ''])
# Out:
# 65

# %%
df_sel['ext_price'] = None
df_sel['ext_weight'] = None

# %%
# for i in range(len(df_sel)):
#     if df_sel['description'][i] != None:
#         desc_text = df_se

# %%
df_sel.tail()
# Out:
#     brand               merchant  \
# 117  None                   ALDI
# 118  None              Walgreens
# 119  None  Woodman's Food Market
# 120  None             Sam's Club
# 121  None               Best Buy
#
#                                                   name category  \
# 117  Mama Cozzi's Pizza Kitchen 12" Gluten Free Del...
# 118                              Frozen Meal Favorites
# 119  $1.50\nBorden Mild Cheddar Slices\n6oz Package...
# 120  Viking Acacia Wood 2-Piece Paddle and Cutting ...
# 121  KitchenAid Metal Food Grinder Attachment - Silver
#
#                                            description current_price  \
# 117                Cheese or Pepperoni\n17.5–17.78 oz.          5.99
# 118  • White Castle Chicken Sandwiches or Burgers, ...
# 119                                               None
# 120  For an elegant serving piece to display at you...         29.98
# 121  Fresh from scratch cooking does not have to ta...         79.99
#
#     price_text  percent_off  \
# 117       Each          NaN
# 118       None         50.0
# 119       None          NaN
# 120       None          NaN
# 121       None         20.0
#
#                                              image_url  \
# 117  http://f.wishabi.net/page_items/209999351/1609...
# 118  http://f.wishabi.net/page_pdf_images/11132380/...
# 119  http://f.wishabi.net/page_items/211919793/1610...
# 120  http://f.wishabi.net/page_pdf_images/11220548/...
# 121  http://f.wishabi.net/page_pdf_images/11224699/...
#
#                                       cutout_image_url ext_price ext_weight
# 117  http://f.wishabi.net/page_items/209999351/1609...      None       None
# 118  http://f.wishabi.net/page_items/209765295/1610...      None       None
# 119  http://f.wishabi.net/page_items/211919793/1610...      None       None
# 120  http://f.wishabi.net/page_items/211444404/1610...      None       None
# 121  http://f.wishabi.net/page_items/211556814/1610...      None       None

# %%
# Extracting price and weight information from combined text.
for i in range(len(df_sel)):
        comb_text = str(df_sel['name'][i])+ ',' + str(df_sel['description'][i]) + ','+  str(df_sel['price_text'][i])
        
        # extract oz 
        tw1 = re.findall('[/ ]\d{1,2,3}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',comb_text)
        tw2 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',comb_text)
        tw3 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw4 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw5 = re.findall('[/,]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw6 = re.findall('[/-]\d{1,2}[/.]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw7 = re.findall('[/,]\d{1,2}[/.]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw8 = re.findall('[/,]\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw9 = re.findall('[/ ]\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',comb_text)
        tw10 = re.findall('\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw11 = re.findall('\d{1,2}[/.]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw12 = re.findall('[/-]\d{1}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw13 =  re.findall('[/ ]\d{1,2,3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw14 = re.findall('[/-]\d{1,2}[/.]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw15 = re.findall('[/-]\d{2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw16 = re.findall('\d{3}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw17 = re.findall('[/-]\d{2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw18 = re.findall('[/ ]\d{1}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw19 = re.findall('\d{2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
        tw20 = re.findall('\d{1}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',comb_text)
              
        #extract lb 
        tw21 = re.findall('\d{3}[/ ]\d{2}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw22 = re.findall('[/$]\d{3}[//](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw23 = re.findall('[/$]\d{3}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw24 = re.findall('[/$]\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw25 = re.findall('\d{3}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw26 = re.findall('\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        
        tw27 = re.findall('[/$]\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw28 = re.findall('[/,](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw29 = re.findall('[/ ]\d{1}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw30 = re.findall('\d{3}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw31 = re.findall('\d{3}(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw32 = re.findall('\d{1}[/.]\d{2} [/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw33 = re.findall('[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)[/ ]',comb_text)
        tw34 = re.findall('\d{3}[\n](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)',comb_text)
        tw35 = re.findall('(?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.)[\n]\d{3}',comb_text)
        tw36 = re.findall('\d{1}[/ ](?:LB|LB.|lb|lb.|Lb|Lb.|lB|lB.|Lbs.)[\n][/$]\d{3}',comb_text)
                   
        ftw = tw1 or tw2 or tw3 or tw4 or tw5 or tw6  \
              or tw7 or tw8 or tw9 or tw10 or tw11 or tw12 \
              or tw13 or tw14 or tw15 or tw16 or tw17 or tw18  \
              or tw19 or tw20 or tw21 or tw22 or tw23 or tw24  \
              or tw25 or tw26 or tw27 or tw28 or tw29 or tw30  \
              or tw31 or tw32 or tw33 or tw34 or tw35 or tw36
        
        #print(i, ftw, comb_text)
        if ftw != []:
            df_sel['ext_weight'][i] = ftw[0]
        if df_sel['current_price'][i] == '':
            mtxt_name = df_sel['name'][i]

            #extract price 
            mtp1 = re.findall('[/$]\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',mtxt_name)
            mtp2 = re.findall('\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',mtxt_name)
            mtp3 = re.findall('[/$]\d{1,2}[/.]\d{2}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',mtxt_name)
            mtp4 = re.findall('[/$]\d{1,2}[/.]\d{2}',mtxt_name)

            mftp = mtp1 or mtp2 or mtp3 or mtp4
            
            if mftp != []:         
                df_sel['ext_price'][i] = mftp[0] 

            #print(i, mftp, mtxt_name)
        
# #         # extract weight unit
# #         tu1 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
# #         tu2 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
# #         tu3 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
# #         tu4 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
        
# #         ftu = tu1 or tu2 or tu3 or tu4
        
# #         if ftp != []:                    
# #             df_sel['calc_price'][i] = ftp[0]
# #         if ftu != []:         
#             df_sel['calc_weight'][i] = ftu[0]

# %%
# # Extracting price and weight information from name column.
# for i in range(len(df_sel)):
#     if df_sel['current_price'][i] == '':
#         txt_name = df_sel['name'][i]
        
#         #extract price only
#         tp1 = re.findall('[/$]\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',txt_name)
#         tp2 = re.findall('\d{3}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',txt_name)
#         tp3 = re.findall('[/$]\d{1,2}[/.]\d{2}[/ ](?:Lb|lb|lb.|Lb.|LB|LB.)',txt_name)
#         tp4 = re.findall('[/$]\d{1,2}[/.]\d{2}',txt_name)
              
#         ftp = tp1 or tp2 or tp3 or tp4
        
#         # extract weight unit
#         tu1 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
#         tu2 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)[/ ]',txt_name)
#         tu3 = re.findall('[/ ]\d{1,2}[/ ](?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
#         tu4 = re.findall('[/ ]\d{1,2}(?:OZ|OZ.|oz|oz.|Oz|Oz.|oZ|oZ.)',txt_name)
        
#         ftu = tu1 or tu2 or tu3 or tu4
        
#         if ftp != []:                    
#             df_sel['calc_price'][i] = ftp[0]
#         if ftu != []:         
#             df_sel['calc_weight'][i] = ftu[0]

# %%
df_sel['ext_price'].unique()
# Out:
# array([None, '$4.99', '$3.49', '$3.49 lb', '$3.99', '$2.99', '349 LB',
#        '$899/LB', '499 LB', '$499 lb', '379 LB', '$449 lb', '$2.49',
#        '$5.99', '$1.50'], dtype=object)

# %%
df_sel['ext_weight'].unique()
# Out:
# array([' 12 oz. ', ',6 oz', '-6 oz', '-4.5 oz', None, '-8 oz', ' lb. ',
#        ' 4 lb', '-22.5 OZ', ',4.94 oz', ' 8 oz', ',4.4 oz', '106 oz',
#        '399\nLb', '-14oz', ' 8 Oz. ', ',lb', ',8 oz', ' 6 OZ ', ' 36 oz',
#        ' 32 oz', ',7 oz', ' 24 OZ. ', ',32 oz', '7.5 oz', ' 8 oz. ',
#        ' 12 oz', '4.5 oz', '-24 oz', '499\nLb', '499 99 Lb', '349 LB',
#        ',2.12 oz', '-7.25 oz', ' 6 oz', '499 99 LB', '-12 oz', '-2 oz',
#        ' LB. ', '298\nLb', '$899/LB', '498\nLb', '499 LB', '-7.3 oz',
#        '$499 lb', '379 LB', '$449 lb', 'Lb.\n399', '2 Lbs.\n$698',
#        ' Lb. ', '-7.25 OZ', ' 5 oZ. ', ' 6 OZ', ' 8 OZ. ', ' 16 OZ. ',
#        '-5.3 oz', ' 16 Oz. ', ' 10 oz. ', '26.3 oz', ',15 oz', ' 59 oz',
#        '14oz', '-11 oz', '24oz', '5oz', ',22 oz', ' 16 oz, ', '-12 OZ',
#        '-7.6 oz', ',13 oz', '17.78 oz', ' 25 oz', '6oz'], dtype=object)
