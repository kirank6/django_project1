# %%
#Import packages
import requests
import io
import urllib.request
import flipp_extracter
from PIL import Image
from io import BytesIO
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Information needed for data extraction
item_name = 'broccoli'
zip_code = 60565

# %%
#results list of dictionarys of query items
Output = flipp_extracter.search(item_name, zip_code)

# %%
display(len(Output))
# Out:
# 7

# %%
# view dictionary 
Output[0]['item'].items()
# Out:
# dict_items([('id', 541225715), ('flyer_id', 3875890), ('flyer_valid_from', '2021-01-10T00:00:00-05:00'), ('flyer_valid_to', '2021-01-16T23:59:59-05:00'), ('brand', None), ('display_type', 1), ('merchant', 'Meijer'), ('merchant_id', 2281), ('merchant_logo', 'http://images.wishabi.net/merchants/2281/1400708516/medium'), ('name', 'Earthbound Farm Organic Broccoli Florets or Broccoli & Cauliflower'), ('image_url', 'http://f.wishabi.net/page_items/210645000/1610040339/extra_large.jpg'), ('cutout_image_url', 'http://f.wishabi.net/page_items/210645000/1610040339/extra_large.jpg'), ('media', []), ('description', '9 oz.'), ('current_price', '2.79'), ('current_price_range', None), ('pre_price_text', 'sale'), ('category', ''), ('price_text', None), ('sale_story', None), ('original_price', None), ('original_price_range', None), ('in_store_only', False), ('disclaimer_text', None), ('flyer_disclaimer_text', ''), ('valid_from', None), ('valid_to', None), ('timezone', -300), ('sku', None), ('ttm_label', 'Shop Now'), ('ttm_url', None), ('show_details', True), ('review_average_rating', None), ('review_count', 0), ('review_samples', []), ('reviews_most_recent', []), ('specs', []), ('features', []), ('related_items', []), ('shipping_info', {'tag_line': 'Shipping policy', 'details_url': 'https://www.meijer.com/services/more-ways-to-meijer/home-delivery.html'}), ('return_info', {'tag_line': 'Return policy', 'details_url': 'https://help.meijer.com/app/answers/list/c/30'}), ('top', -155.163), ('bottom', -353.163), ('left', 3844.5), ('right', 4089.5), ('percent_off', None), ('dollars_off', None)])

# %%
def select_df(list_dics_all):
    '''
    Results a datafram of selected items reading a list of 
    dictionaries of extracted items.
    '''
    #Reading data from Output dictionary
    selected_cols = ['brand', 'merchant', 'name', 'category', 'description', 
                                           'current_price', 'price_text', 'percent_off','image_url','cutout_image_url']
    df_all_items = pd.DataFrame(columns = selected_cols) # dataframe from selected items

    list_dic_selected_items =[]  # list of dictionaries with selected item desriptions only


    for i in range(len(Output)):
        items_dict = Output[i]['item']
        selected_dict = {}

        for key in items_dict:
            if key in selected_cols:
                selected_dict[key] = items_dict[key]                   
        list_dic_selected_items.append(selected_dict)   #update list with dictinaries for each group
    df_all_items = df_all_items.append(list_dic_selected_items, True)   # append list to dataframe 
    return df_all_items

# %%
df_sel = select_df(Output)

# %%
df_sel.tail(20)
# Out:
#        brand            merchant  \
# 0       None              Meijer
# 1  Birds Eye             Walmart
# 2       None              Meijer
# 3       None  Fresh Thyme Market
# 4       None              Meijer
# 5       None              Hy-Vee
# 6       None          Jewel-Osco
#
#                                                 name category description  \
# 0  Earthbound Farm Organic Broccoli Florets or Br...                9 oz.
# 1               NEW! Birds Eye Cheddar Broccoli Bake                13 oz
# 2                                   Broccoli Crowns*                 None
# 3                    Broccoli Bunches or Cauliflower                 None
# 4                         Mann's Broccoli Cole Slaw*               12 oz.
# 5                               Dole broccoli crowns                 None
# 6                   Broccoli and Cauliflower Florets                 None
#
#   current_price price_text percent_off  \
# 0          2.79       None        None
# 1          3.98       None        None
# 2           1.0       None        None
# 3          0.99         LB        None
# 4           1.0       None        None
# 5          2.49        lb.        None
# 6          3.99        lb.        None
#
#                                            image_url  \
# 0  http://f.wishabi.net/page_items/210645000/1610...
# 1  http://f.wishabi.net/page_pdf_images/11100085/...
# 2  http://f.wishabi.net/page_pdf_images/11168748/...
# 3  http://f.wishabi.net/page_items/210227061/1609...
# 4  http://f.wishabi.net/page_pdf_images/11168748/...
# 5  http://f.wishabi.net/page_items/210498021/1609...
# 6  http://f.wishabi.net/page_pdf_images/11171244/...
#
#                                     cutout_image_url
# 0  http://f.wishabi.net/page_items/210645000/1610...
# 1  http://f.wishabi.net/page_items/209111486/1609...
# 2  http://f.wishabi.net/page_items/210658683/1610...
# 3  http://f.wishabi.net/page_items/210227061/1609...
# 4  http://f.wishabi.net/page_items/210658688/1610...
# 5  http://f.wishabi.net/page_items/210498021/1609...
# 6  http://f.wishabi.net/page_items/210463711/1609...

# %%
len(df_sel['current_price'])
# Out:
# 7

# %%
# for i in range(len(df_sel)):
#     if df_sel['description'][i] != None:
#         desc_text = df_sel['description'][i]
#         print(desc_text)

# %%
len(df_sel[df_sel['current_price'] == ''])
# Out:
# 0

# %%
df_price = df_sel[df_sel['current_price'] != '']

# %%
len(df_price)
# Out:
# 7

# %%
df_price.head()
# Out:
#        brand            merchant  \
# 0       None              Meijer
# 1  Birds Eye             Walmart
# 2       None              Meijer
# 3       None  Fresh Thyme Market
# 4       None              Meijer
#
#                                                 name category description  \
# 0  Earthbound Farm Organic Broccoli Florets or Br...                9 oz.
# 1               NEW! Birds Eye Cheddar Broccoli Bake                13 oz
# 2                                   Broccoli Crowns*                 None
# 3                    Broccoli Bunches or Cauliflower                 None
# 4                         Mann's Broccoli Cole Slaw*               12 oz.
#
#   current_price price_text percent_off  \
# 0          2.79       None        None
# 1          3.98       None        None
# 2           1.0       None        None
# 3          0.99         LB        None
# 4           1.0       None        None
#
#                                            image_url  \
# 0  http://f.wishabi.net/page_items/210645000/1610...
# 1  http://f.wishabi.net/page_pdf_images/11100085/...
# 2  http://f.wishabi.net/page_pdf_images/11168748/...
# 3  http://f.wishabi.net/page_items/210227061/1609...
# 4  http://f.wishabi.net/page_pdf_images/11168748/...
#
#                                     cutout_image_url
# 0  http://f.wishabi.net/page_items/210645000/1610...
# 1  http://f.wishabi.net/page_items/209111486/1609...
# 2  http://f.wishabi.net/page_items/210658683/1610...
# 3  http://f.wishabi.net/page_items/210227061/1609...
# 4  http://f.wishabi.net/page_items/210658688/1610...

# %%
df_sorted = df_price.sort_values(by='current_price')

# %%
df_sorted.head()
# Out:
#   brand            merchant  \
# 3  None  Fresh Thyme Market
# 2  None              Meijer
# 4  None              Meijer
# 5  None              Hy-Vee
# 0  None              Meijer
#
#                                                 name category description  \
# 3                    Broccoli Bunches or Cauliflower                 None
# 2                                   Broccoli Crowns*                 None
# 4                         Mann's Broccoli Cole Slaw*               12 oz.
# 5                               Dole broccoli crowns                 None
# 0  Earthbound Farm Organic Broccoli Florets or Br...                9 oz.
#
#   current_price price_text percent_off  \
# 3          0.99         LB        None
# 2           1.0       None        None
# 4           1.0       None        None
# 5          2.49        lb.        None
# 0          2.79       None        None
#
#                                            image_url  \
# 3  http://f.wishabi.net/page_items/210227061/1609...
# 2  http://f.wishabi.net/page_pdf_images/11168748/...
# 4  http://f.wishabi.net/page_pdf_images/11168748/...
# 5  http://f.wishabi.net/page_items/210498021/1609...
# 0  http://f.wishabi.net/page_items/210645000/1610...
#
#                                     cutout_image_url
# 3  http://f.wishabi.net/page_items/210227061/1609...
# 2  http://f.wishabi.net/page_items/210658683/1610...
# 4  http://f.wishabi.net/page_items/210658688/1610...
# 5  http://f.wishabi.net/page_items/210498021/1609...
# 0  http://f.wishabi.net/page_items/210645000/1610...

# %%
df_sorted['current_price'].unique()
# Out:
# array(['0.99', '1.0', '2.49', '2.79', '3.98', '3.99'], dtype=object)

# %%
df_sorted = df_sorted.reset_index()

# %%
lowest_price = df_sorted['current_price'].min()
highest_price = df_sorted['current_price'].max()

# %%
print("Lowest price: ", lowest_price)
print("Highest price: ", highest_price)
# Out:
# Lowest price:  0.99
# Highest price:  3.99

# %%
#Lowest price item
store_name = df_sorted['merchant'][0]
current_price = df_sorted['current_price'][0]
item_image = df_sorted['image_url'][0]
#read the image
with urllib.request.urlopen(item_image ) as url:
     ff = io.BytesIO(url.read())

img = Image.open(ff)
display(store_name, current_price )
display(img)
# Out:
# 'Fresh Thyme Market'
# '0.99'
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x343 at 0x13A50208>
